# %%
import random
import json

# %%
for x in range(5):
    random.seed(x)    
    ctom_dict = {}

    blocks = ["Block"+str(x) for x in range(1,15)]

    targets = [x for x in range(1,15)]
    shuffled_targets = targets.copy()
    random.shuffle(shuffled_targets)

    stimuli = ["face","video","convo","self","partnerState","partnerTrait"]
    traits = ["Bossy","Easygoing","Passive"]
    three_dims = ["Valence","Rationality","Impact"]

    def trait_shuffler(input):
        random.shuffle(input)
        defaults = [0] * len(input)
        return dict(zip(input,defaults))

    for i in blocks:
        ctom_dict[str(i)] = {}

    index=0
    for key in ctom_dict:
        ctom_dict[key]= {"target"+str(shuffled_targets[index]): {}}
        index += 1

    for key in ctom_dict:
        for k in ctom_dict[key].keys():
            for stim in stimuli:
                ctom_dict[key][k][stim]={}

    for key in ctom_dict:
        for k in ctom_dict[key].keys():
            for stim in ctom_dict[key][k].keys():
                if stim =="self" or stim=="partnerState":
                    ctom_dict[key][k][stim] = trait_shuffler(three_dims)
                else: 
                    ctom_dict[key][k][stim] = trait_shuffler(traits)
    
    with open('ctom-data_'+str(x)+'.json', 'w') as fp:
        json.dump(ctom_dict, fp)

# %%
ctom_dict
# Out:
# {'Block1': {'target10': {'face': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0},
#    'video': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'convo': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0},
#    'self': {'Rationality': 0, 'Impact': 0, 'Valence': 0},
#    'partnerState': {'Rationality': 0, 'Impact': 0, 'Valence': 0},
#    'partnerTrait': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0}}},
#  'Block2': {'target13': {'face': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0},
#    'video': {'Bossy': 0, 'Passive': 0, 'Easygoing': 0},
#    'convo': {'Easygoing': 0, 'Passive': 0, 'Bossy': 0},
#    'self': {'Rationality': 0, 'Impact': 0, 'Valence': 0},
#    'partnerState': {'Impact': 0, 'Rationality': 0, 'Valence': 0},
#    'partnerTrait': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0}}},
#  'Block3': {'target6': {'face': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0},
#    'video': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0},
#    'convo': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0},
#    'self': {'Impact': 0, 'Rationality': 0, 'Valence': 0},
#    'partnerState': {'Rationality': 0, 'Impact': 0, 'Valence': 0},
#    'partnerTrait': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0}}},
#  'Block4': {'target9': {'face': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'video': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0},
#    'convo': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0},
#    'self': {'Rationality': 0, 'Valence': 0, 'Impact': 0},
#    'partnerState': {'Valence': 0, 'Impact': 0, 'Rationality': 0},
#    'partnerTrait': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0}}},
#  'Block5': {'target14': {'face': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'video': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'convo': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'self': {'Impact': 0, 'Rationality': 0, 'Valence': 0},
#    'partnerState': {'Valence': 0, 'Rationality': 0, 'Impact': 0},
#    'partnerTrait': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0}}},
#  'Block6': {'target11': {'face': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0},
#    'video': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'convo': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'self': {'Rationality': 0, 'Valence': 0, 'Impact': 0},
#    'partnerState': {'Impact': 0, 'Rationality': 0, 'Valence': 0},
#    'partnerTrait': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0}}},
#  'Block7': {'target1': {'face': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'video': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0},
#    'convo': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'self': {'Valence': 0, 'Impact': 0, 'Rationality': 0},
#    'partnerState': {'Rationality': 0, 'Impact': 0, 'Valence': 0},
#    'partnerTrait': {'Bossy': 0, 'Passive': 0, 'Easygoing': 0}}},
#  'Block8': {'target12': {'face': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0},
#    'video': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0},
#    'convo': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'self': {'Valence': 0, 'Impact': 0, 'Rationality': 0},
#    'partnerState': {'Impact': 0, 'Valence': 0, 'Rationality': 0},
#    'partnerTrait': {'Easygoing': 0, 'Passive': 0, 'Bossy': 0}}},
#  'Block9': {'target3': {'face': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0},
#    'video': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'convo': {'Easygoing': 0, 'Passive': 0, 'Bossy': 0},
#    'self': {'Rationality': 0, 'Impact': 0, 'Valence': 0},
#    'partnerState': {'Valence': 0, 'Rationality': 0, 'Impact': 0},
#    'partnerTrait': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0}}},
#  'Block10': {'target8': {'face': {'Bossy': 0, 'Passive': 0, 'Easygoing': 0},
#    'video': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0},
#    'convo': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0},
#    'self': {'Impact': 0, 'Valence': 0, 'Rationality': 0},
#    'partnerState': {'Valence': 0, 'Rationality': 0, 'Impact': 0},
#    'partnerTrait': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0}}},
#  'Block11': {'target7': {'face': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0},
#    'video': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0},
#    'convo': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0},
#    'self': {'Valence': 0, 'Rationality': 0, 'Impact': 0},
#    'partnerState': {'Rationality': 0, 'Valence': 0, 'Impact': 0},
#    'partnerTrait': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0}}},
#  'Block12': {'target2': {'face': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0},
#    'video': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0},
#    'convo': {'Bossy': 0, 'Passive': 0, 'Easygoing': 0},
#    'self': {'Impact': 0, 'Valence': 0, 'Rationality': 0},
#    'partnerState': {'Impact': 0, 'Rationality': 0, 'Valence': 0},
#    'partnerTrait': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0}}},
#  'Block13': {'target5': {'face': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'video': {'Easygoing': 0, 'Bossy': 0, 'Passive': 0},
#    'convo': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'self': {'Rationality': 0, 'Valence': 0, 'Impact': 0},
#    'partnerState': {'Impact': 0, 'Valence': 0, 'Rationality': 0},
#    'partnerTrait': {'Easygoing': 0, 'Passive': 0, 'Bossy': 0}}},
#  'Block14': {'target4': {'face': {'Passive': 0, 'Easygoing': 0, 'Bossy': 0},
#    'video': {'Bossy': 0, 'Easygoing': 0, 'Passive': 0},
#    'convo': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0},
#    'self': {'Rationality': 0, 'Impact': 0, 'Valence': 0},
#    'partnerState': {'Valence': 0, 'Rationality': 0, 'Impact': 0},
#    'partnerTrait': {'Passive': 0, 'Bossy': 0, 'Easygoing': 0}}}}
