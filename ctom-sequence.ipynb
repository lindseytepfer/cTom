# %%
import random
import json

# %%
stimuli = ["face","video","convo","self","partnerState","partnerTrait"]
targets = [x for x in range(1,15)]
shuffled_targets = targets.copy()
random.shuffle(shuffled_targets)
traits = ["Bossy","Easygoing","Passive"]
three_dims = ["Valence","Rationality","Impact"]
ctom_dict = {}

blocks = ["Block"+str(x) for x in range(1,8)]
stim_combos = []

def trait_shuffler():
    random.shuffle(traits)
    random.shuffle(three_dims)
    for i in stimuli:
        if i == "self" or i=="partnerState":
            for d in three_dims:
                stim_combos.append(i+d)
        else:
            for j in traits:
                stim_combos.append(i + j)
    return(stim_combos)

defaults = [0] * 18

stim_ratings = dict(zip(stim_combos,defaults))

for i in blocks:
    ctom_dict[str(i)] = {}

index=0
for i in range(2):
    for key in ctom_dict:
        ctom_dict[key]["target"+str(shuffled_targets[index])] = {}
        index += 1

for keys in ctom_dict:
   for k in ctom_dict[keys].keys():
       stim_combos = []
       trait_shuffler()
       stim_ratings = dict(zip(stim_combos,defaults))
       ctom_dict[keys][k] = stim_ratings

# %%
ctom_dict
# Out:
# {'Block1': {'target2': {'faceEasygoing': 0,
#    'faceBossy': 0,
#    'facePassive': 0,
#    'videoEasygoing': 0,
#    'videoBossy': 0,
#    'videoPassive': 0,
#    'convoEasygoing': 0,
#    'convoBossy': 0,
#    'convoPassive': 0,
#    'selfImpact': 0,
#    'selfValence': 0,
#    'selfRationality': 0,
#    'partnerStateImpact': 0,
#    'partnerStateValence': 0,
#    'partnerStateRationality': 0,
#    'partnerTraitEasygoing': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitPassive': 0},
#   'target1': {'facePassive': 0,
#    'faceEasygoing': 0,
#    'faceBossy': 0,
#    'videoPassive': 0,
#    'videoEasygoing': 0,
#    'videoBossy': 0,
#    'convoPassive': 0,
#    'convoEasygoing': 0,
#    'convoBossy': 0,
#    'selfRationality': 0,
#    'selfValence': 0,
#    'selfImpact': 0,
#    'partnerStateRationality': 0,
#    'partnerStateValence': 0,
#    'partnerStateImpact': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitEasygoing': 0,
#    'partnerTraitBossy': 0}},
#  'Block2': {'target6': {'faceBossy': 0,
#    'facePassive': 0,
#    'faceEasygoing': 0,
#    'videoBossy': 0,
#    'videoPassive': 0,
#    'videoEasygoing': 0,
#    'convoBossy': 0,
#    'convoPassive': 0,
#    'convoEasygoing': 0,
#    'selfImpact': 0,
#    'selfValence': 0,
#    'selfRationality': 0,
#    'partnerStateImpact': 0,
#    'partnerStateValence': 0,
#    'partnerStateRationality': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitEasygoing': 0},
#   'target7': {'faceBossy': 0,
#    'facePassive': 0,
#    'faceEasygoing': 0,
#    'videoBossy': 0,
#    'videoPassive': 0,
#    'videoEasygoing': 0,
#    'convoBossy': 0,
#    'convoPassive': 0,
#    'convoEasygoing': 0,
#    'selfRationality': 0,
#    'selfImpact': 0,
#    'selfValence': 0,
#    'partnerStateRationality': 0,
#    'partnerStateImpact': 0,
#    'partnerStateValence': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitEasygoing': 0}},
#  'Block3': {'target10': {'faceEasygoing': 0,
#    'facePassive': 0,
#    'faceBossy': 0,
#    'videoEasygoing': 0,
#    'videoPassive': 0,
#    'videoBossy': 0,
#    'convoEasygoing': 0,
#    'convoPassive': 0,
#    'convoBossy': 0,
#    'selfValence': 0,
#    'selfRationality': 0,
#    'selfImpact': 0,
#    'partnerStateValence': 0,
#    'partnerStateRationality': 0,
#    'partnerStateImpact': 0,
#    'partnerTraitEasygoing': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitBossy': 0},
#   'target5': {'facePassive': 0,
#    'faceBossy': 0,
#    'faceEasygoing': 0,
#    'videoPassive': 0,
#    'videoBossy': 0,
#    'videoEasygoing': 0,
#    'convoPassive': 0,
#    'convoBossy': 0,
#    'convoEasygoing': 0,
#    'selfImpact': 0,
#    'selfRationality': 0,
#    'selfValence': 0,
#    'partnerStateImpact': 0,
#    'partnerStateRationality': 0,
#    'partnerStateValence': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitEasygoing': 0}},
#  'Block4': {'target12': {'faceBossy': 0,
#    'faceEasygoing': 0,
#    'facePassive': 0,
#    'videoBossy': 0,
#    'videoEasygoing': 0,
#    'videoPassive': 0,
#    'convoBossy': 0,
#    'convoEasygoing': 0,
#    'convoPassive': 0,
#    'selfRationality': 0,
#    'selfValence': 0,
#    'selfImpact': 0,
#    'partnerStateRationality': 0,
#    'partnerStateValence': 0,
#    'partnerStateImpact': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitEasygoing': 0,
#    'partnerTraitPassive': 0},
#   'target9': {'faceBossy': 0,
#    'facePassive': 0,
#    'faceEasygoing': 0,
#    'videoBossy': 0,
#    'videoPassive': 0,
#    'videoEasygoing': 0,
#    'convoBossy': 0,
#    'convoPassive': 0,
#    'convoEasygoing': 0,
#    'selfValence': 0,
#    'selfImpact': 0,
#    'selfRationality': 0,
#    'partnerStateValence': 0,
#    'partnerStateImpact': 0,
#    'partnerStateRationality': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitEasygoing': 0}},
#  'Block5': {'target8': {'facePassive': 0,
#    'faceBossy': 0,
#    'faceEasygoing': 0,
#    'videoPassive': 0,
#    'videoBossy': 0,
#    'videoEasygoing': 0,
#    'convoPassive': 0,
#    'convoBossy': 0,
#    'convoEasygoing': 0,
#    'selfRationality': 0,
#    'selfImpact': 0,
#    'selfValence': 0,
#    'partnerStateRationality': 0,
#    'partnerStateImpact': 0,
#    'partnerStateValence': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitEasygoing': 0},
#   'target14': {'faceBossy': 0,
#    'faceEasygoing': 0,
#    'facePassive': 0,
#    'videoBossy': 0,
#    'videoEasygoing': 0,
#    'videoPassive': 0,
#    'convoBossy': 0,
#    'convoEasygoing': 0,
#    'convoPassive': 0,
#    'selfImpact': 0,
#    'selfValence': 0,
#    'selfRationality': 0,
#    'partnerStateImpact': 0,
#    'partnerStateValence': 0,
#    'partnerStateRationality': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitEasygoing': 0,
#    'partnerTraitPassive': 0}},
#  'Block6': {'target11': {'facePassive': 0,
#    'faceEasygoing': 0,
#    'faceBossy': 0,
#    'videoPassive': 0,
#    'videoEasygoing': 0,
#    'videoBossy': 0,
#    'convoPassive': 0,
#    'convoEasygoing': 0,
#    'convoBossy': 0,
#    'selfImpact': 0,
#    'selfValence': 0,
#    'selfRationality': 0,
#    'partnerStateImpact': 0,
#    'partnerStateValence': 0,
#    'partnerStateRationality': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitEasygoing': 0,
#    'partnerTraitBossy': 0},
#   'target13': {'facePassive': 0,
#    'faceBossy': 0,
#    'faceEasygoing': 0,
#    'videoPassive': 0,
#    'videoBossy': 0,
#    'videoEasygoing': 0,
#    'convoPassive': 0,
#    'convoBossy': 0,
#    'convoEasygoing': 0,
#    'selfValence': 0,
#    'selfRationality': 0,
#    'selfImpact': 0,
#    'partnerStateValence': 0,
#    'partnerStateRationality': 0,
#    'partnerStateImpact': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitEasygoing': 0}},
#  'Block7': {'target3': {'faceBossy': 0,
#    'facePassive': 0,
#    'faceEasygoing': 0,
#    'videoBossy': 0,
#    'videoPassive': 0,
#    'videoEasygoing': 0,
#    'convoBossy': 0,
#    'convoPassive': 0,
#    'convoEasygoing': 0,
#    'selfRationality': 0,
#    'selfValence': 0,
#    'selfImpact': 0,
#    'partnerStateRationality': 0,
#    'partnerStateValence': 0,
#    'partnerStateImpact': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitEasygoing': 0},
#   'target4': {'faceBossy': 0,
#    'facePassive': 0,
#    'faceEasygoing': 0,
#    'videoBossy': 0,
#    'videoPassive': 0,
#    'videoEasygoing': 0,
#    'convoBossy': 0,
#    'convoPassive': 0,
#    'convoEasygoing': 0,
#    'selfImpact': 0,
#    'selfRationality': 0,
#    'selfValence': 0,
#    'partnerStateImpact': 0,
#    'partnerStateRationality': 0,
#    'partnerStateValence': 0,
#    'partnerTraitBossy': 0,
#    'partnerTraitPassive': 0,
#    'partnerTraitEasygoing': 0}}}

# %%
with open('ctom-trials.json', 'w') as fp:
    json.dump(ctom_dict, fp)
